# %%
import csv

# %%
# root_path = "C:/Users/KIIT/Desktop/Stratlytics/02_Bootcamp/04_Python/"
root_path = "/home/name04/Desktop/Anjaneya/02_Bootcamp/04_Python/Bootcamp_Python/"
inv_file_path = root_path + "01_Data/dirty/inventory.csv"
test_inv_file_path = root_path + "01_Data/dirty/test_inventory.csv"

# %%
def read_inventory(file_path):
    '''Generator-based file reader'''
    with open(file_path, newline="") as f:
        reader = csv.DictReader(f)
        for row in reader:
            yield row

# %%
def validate_headers(row):
    '''Validates exact header matching for each row'''
    expected_headers = {"inventory_id","snapshot_date","dealer_id","product_id","on_hand_qty","on_order_qty","reorder_point","reorder_qty","last_restock_date","last_sale_date"}
    actual_headers = set(row.keys())
    return actual_headers == expected_headers

# %%
def main(file_path,limit=5):
    '''Orchestrates file read and validation upto a specified limit'''
    valid_row_count = 0
    row_count = 0
    for row in read_inventory(file_path):
        row_count += 1
        if valid_row_count >= limit:
            break
        if validate_headers(row):
            valid_row_count += 1
            print(f"[INFO] Valid Row {valid_row_count}:\n{row}")
        else:
            print(f"[INFO] Header mismatch for file row number {row_count}")
            raise ValueError("Header mismatch")
    print(f"[INFO] Found and printed {valid_row_count} rows.")

# %%
main(inv_file_path)
# Out:
# [INFO] Valid Row 1:
# {'inventory_id': 'INV-20251130-00001', 'snapshot_date': '2025-11-30', 'dealer_id': '40', 'product_id': '134', 'on_hand_qty': '17', 'on_order_qty': '0', 'reorder_point': '16', 'reorder_qty': '60', 'last_restock_date': '2025-11-22', 'last_sale_date': '2025-11-03'}
# [INFO] Valid Row 2:
# {'inventory_id': 'INV-20251130-00002', 'snapshot_date': '2025-11-30', 'dealer_id': '40', 'product_id': '23', 'on_hand_qty': '215', 'on_order_qty': '18', 'reorder_point': '17', 'reorder_qty': '30', 'last_restock_date': '2025-11-15', 'last_sale_date': '2025-11-12'}
# [INFO] Valid Row 3:
# {'inventory_id': 'INV-20251130-00003', 'snapshot_date': '2025-11-30', 'dealer_id': '40', 'product_id': '223', 'on_hand_qty': '73', 'on_order_qty': '10', 'reorder_point': '18', 'reorder_qty': '31', 'last_restock_date': '2025-10-30', 'last_sale_date': '2025-11-23'}
# [INFO] Valid Row 4:
# {'inventory_id': 'INV-20251130-00004', 'snapshot_date': '2025-11-30', 'dealer_id': '40', 'product_id': '130', 'on_hand_qty': '61', 'on_order_qty': '47', 'reorder_point': '9', 'reorder_qty': '30', 'last_restock_date': '', 'last_sale_date': '2025-11-19'}
# [INFO] Valid Row 5:
# {'inventory_id': 'INV-20251130-00005', 'snapshot_date': '2025-11-30', 'dealer_id': '40', 'product_id': '265', 'on_hand_qty': '5', 'on_order_qty': '39', 'reorder_point': '8', 'reorder_qty': '20', 'last_restock_date': '', 'last_sale_date': '2025-11-04'}
# [INFO] Found and printed 5 rows.

# %%
main(test_inv_file_path)
# Out:
# [INFO] Header mismatch for file row number 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 main(test_inv_file_path)
#
# Cell In[5], line 14, in main(file_path, limit)
#      12     else:
#      13         print(f"[INFO] Header mismatch for file row number {row_count}")
# ---> 14         raise ValueError("Header mismatch")
#      15 print(f"[INFO] Found and printed {valid_row_count} rows.")
#
# ValueError: Header mismatch
