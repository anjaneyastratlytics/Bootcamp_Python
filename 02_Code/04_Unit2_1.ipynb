# %%
import csv

# %%
import logging

logging.basicConfig(
    level = logging.INFO,
    format = "%(asctime)s | %(levelname)s | %(message)s"
)

# %%
# root_path = "C:/Users/KIIT/Desktop/Stratlytics/02_Bootcamp/04_Python/"
root_path = "/home/name04/Desktop/Anjaneya/02_Bootcamp/04_Python/Bootcamp_Python/"
inv_file_path = root_path + "01_Data/dirty/inventory.csv"
test_inv_file_path = root_path + "01_Data/dirty/test_inventory.csv"

# %%
def read_inventory(file_path):
    '''Generator-based file reader'''
    with open(file_path, newline="") as f:
        reader = csv.DictReader(f)
        for row in reader:
            yield row

# %%
def validate_headers(row):
    '''Validates exact header matching for each row'''
    expected_headers = {"inventory_id","snapshot_date","dealer_id","product_id","on_hand_qty","on_order_qty","reorder_point","reorder_qty","last_restock_date","last_sale_date"}
    actual_headers = set(row.keys())
    return actual_headers == expected_headers

# %%
def main(file_path,limit=5):
    '''Orchestrates file read and validation upto a specified limit'''
    valid_row_count = 0
    row_count = 0
    logging.info(f"Ingestion started | {file_path.split('/')[-1]}")
    for row in read_inventory(file_path):
        if valid_row_count >= limit:
            break
        row_count += 1
        if validate_headers(row):
            valid_row_count += 1
            logging.info(f"Validated | inventory_id = {row.get('inventory_id')}")
        else:
            logging.error(f" Header mismatch | inventory_id = {row.get('inventory_id')}")
    logging.info(f"Validation Complete | Valid rows = {valid_row_count}, Invalid rows = {row_count-valid_row_count}")

# %%
main(inv_file_path)
# Out:
# 2026-07-14 14:59:20,827 | INFO | Ingestion started | inventory.csv
# 2026-07-14 14:59:20,831 | INFO | Validated | inventory_id = INV-20251130-00001
# 2026-07-14 14:59:20,835 | INFO | Validated | inventory_id = INV-20251130-00002
# 2026-07-14 14:59:20,839 | INFO | Validated | inventory_id = INV-20251130-00003
# 2026-07-14 14:59:20,840 | INFO | Validated | inventory_id = INV-20251130-00004
# 2026-07-14 14:59:20,843 | INFO | Validated | inventory_id = INV-20251130-00005
# 2026-07-14 14:59:20,844 | INFO | Validation Complete | Valid rows = 5, Invalid rows = 0

# %%
main(test_inv_file_path)
# Out:
# 2026-07-14 14:59:22,286 | INFO | Ingestion started | test_inventory.csv
# 2026-07-14 14:59:22,292 | ERROR |  Header mismatch | inventory_id = INV-20251130-00001
# 2026-07-14 14:59:22,293 | ERROR |  Header mismatch | inventory_id = INV-20251130-00002
# 2026-07-14 14:59:22,294 | ERROR |  Header mismatch | inventory_id = INV-20251130-00003
# 2026-07-14 14:59:22,296 | ERROR |  Header mismatch | inventory_id = INV-20251130-00004
# 2026-07-14 14:59:22,298 | ERROR |  Header mismatch | inventory_id = INV-20251130-00005
# 2026-07-14 14:59:22,302 | ERROR |  Header mismatch | inventory_id = INV-20251130-00006
# 2026-07-14 14:59:22,309 | ERROR |  Header mismatch | inventory_id = INV-20251130-00007
# 2026-07-14 14:59:22,310 | ERROR |  Header mismatch | inventory_id = INV-20251130-00008
# 2026-07-14 14:59:22,313 | ERROR |  Header mismatch | inventory_id = INV-20251130-00009
# 2026-07-14 14:59:22,320 | ERROR |  Header mismatch | inventory_id = INV-20251130-00010
# 2026-07-14 14:59:22,323 | ERROR |  Header mismatch | inventory_id = INV-20251130-00011
# 2026-07-14 14:59:22,327 | ERROR |  Header mismatch | inventory_id = INV-20251130-00012
# 2026-07-14 14:59:22,333 | ERROR |  Header mismatch | inventory_id = INV-20251130-00013
# 2026-07-14 14:59:22,338 | ERROR |  Header mismatch | inventory_id = INV-20251130-00014
# 2026-07-14 14:59:22,344 | ERROR |  Header mismatch | inventory_id = INV-20251130-00015
# 2026-07-14 14:59:22,347 | ERROR |  Header mismatch | inventory_id = INV-20251130-00016
# 2026-07-14 14:59:22,353 | ERROR |  Header mismatch | inventory_id = INV-20251130-00017
# 2026-07-14 14:59:22,354 | ERROR |  Header mismatch | inventory_id = INV-20251130-00018
# 2026-07-14 14:59:22,357 | ERROR |  Header mismatch | inventory_id = INV-20251130-00019
# 2026-07-14 14:59:22,361 | ERROR |  Header mismatch | inventory_id = INV-20251130-00020
# 2026-07-14 14:59:22,364 | ERROR |  Header mismatch | inventory_id = INV-20251130-00021
# 2026-07-14 14:59:22,369 | ERROR |  Header mismatch | inventory_id = INV-20251130-00022
# 2026-07-14 14:59:22,372 | ERROR |  Header mismatch | inventory_id = INV-20251130-00023
# 2026-07-14 14:59:22,385 | ERROR |  Header mismatch | inventory_id = INV-20251130-00024
# 2026-07-14 14:59:22,408 | ERROR |  Header mismatch | inventory_id = INV-20251130-00025
# 2026-07-14 14:59:22,409 | ERROR |  Header mismatch | inventory_id = INV-20251130-00026
# 2026-07-14 14:59:22,417 | ERROR |  Header mismatch | inventory_id = INV-20251130-00027
# 2026-07-14 14:59:22,425 | ERROR |  Header mismatch | inventory_id = INV-20251130-00028
# 2026-07-14 14:59:22,432 | ERROR |  Header mismatch | inventory_id = INV-20251130-00029
# 2026-07-14 14:59:22,438 | ERROR |  Header mismatch | inventory_id = INV-20251130-00030
# 2026-07-14 14:59:22,443 | ERROR |  Header mismatch | inventory_id = INV-20251130-00031
# 2026-07-14 14:59:22,450 | ERROR |  Header mismatch | inventory_id = INV-20251130-00032
# 2026-07-14 14:59:22,463 | ERROR |  Header mismatch | inventory_id = INV-20251130-00033
# 2026-07-14 14:59:22,470 | ERROR |  Header mismatch | inventory_id = INV-20251130-00034
# 2026-07-14 14:59:22,484 | ERROR |  Header mismatch | inventory_id = INV-20251130-00035
# 2026-07-14 14:59:22,494 | ERROR |  Header mismatch | inventory_id = INV-20251130-00036
# 2026-07-14 14:59:22,497 | ERROR |  Header mismatch | inventory_id = INV-20251130-00037
# 2026-07-14 14:59:22,500 | ERROR |  Header mismatch | inventory_id = INV-20251130-00038
# 2026-07-14 14:59:22,503 | ERROR |  Header mismatch | inventory_id = INV-20251130-00039
# 2026-07-14 14:59:22,506 | ERROR |  Header mismatch | inventory_id = INV-20251130-00040
# 2026-07-14 14:59:22,507 | ERROR |  Header mismatch | inventory_id = INV-20251130-00041
# 2026-07-14 14:59:22,511 | ERROR |  Header mismatch | inventory_id = INV-20251130-00042
# 2026-07-14 14:59:22,513 | ERROR |  Header mismatch | inventory_id = INV-20251130-00043
# 2026-07-14 14:59:22,514 | ERROR |  Header mismatch | inventory_id = INV-20251130-00044
# 2026-07-14 14:59:22,515 | ERROR |  Header mismatch | inventory_id = INV-20251130-00045
# 2026-07-14 14:59:22,519 | ERROR |  Header mismatch | inventory_id = INV-20251130-00046
# 2026-07-14 14:59:22,522 | ERROR |  Header mismatch | inventory_id = INV-20251130-00047
# 2026-07-14 14:59:22,523 | ERROR |  Header mismatch | inventory_id = INV-20251130-00048
# 2026-07-14 14:59:22,524 | ERROR |  Header mismatch | inventory_id = INV-20251130-00049
# 2026-07-14 14:59:22,525 | ERROR |  Header mismatch | inventory_id = INV-20251130-00050
# 2026-07-14 14:59:22,527 | ERROR |  Header mismatch | inventory_id = INV-20251130-00051
# 2026-07-14 14:59:22,527 | ERROR |  Header mismatch | inventory_id = INV-20251130-00052
# 2026-07-14 14:59:22,528 | ERROR |  Header mismatch | inventory_id = INV-20251130-00053
# 2026-07-14 14:59:22,530 | ERROR |  Header mismatch | inventory_id = INV-20251130-00054
# 2026-07-14 14:59:22,530 | ERROR |  Header mismatch | inventory_id = INV-20251130-00055
# 2026-07-14 14:59:22,532 | ERROR |  Header mismatch | inventory_id = INV-20251130-00056
# 2026-07-14 14:59:22,533 | ERROR |  Header mismatch | inventory_id = INV-20251130-00057
# 2026-07-14 14:59:22,533 | ERROR |  Header mismatch | inventory_id = INV-20251130-00058
# 2026-07-14 14:59:22,535 | ERROR |  Header mismatch | inventory_id = INV-20251130-00059
# 2026-07-14 14:59:22,535 | ERROR |  Header mismatch | inventory_id = INV-20251130-00060
# 2026-07-14 14:59:22,536 | ERROR |  Header mismatch | inventory_id = INV-20251130-00061
# 2026-07-14 14:59:22,538 | ERROR |  Header mismatch | inventory_id = INV-20251130-00062
# 2026-07-14 14:59:22,540 | ERROR |  Header mismatch | inventory_id = INV-20251130-00063
# 2026-07-14 14:59:22,541 | ERROR |  Header mismatch | inventory_id = INV-20251130-00064
# 2026-07-14 14:59:22,544 | ERROR |  Header mismatch | inventory_id = INV-20251130-00065
# 2026-07-14 14:59:22,546 | ERROR |  Header mismatch | inventory_id = INV-20251130-00066
# 2026-07-14 14:59:22,548 | ERROR |  Header mismatch | inventory_id = INV-20251130-00067
# 2026-07-14 14:59:22,550 | ERROR |  Header mismatch | inventory_id = INV-20251130-00068
# 2026-07-14 14:59:22,554 | ERROR |  Header mismatch | inventory_id = INV-20251130-00069
# 2026-07-14 14:59:22,559 | ERROR |  Header mismatch | inventory_id = INV-20251130-00070
# 2026-07-14 14:59:22,561 | ERROR |  Header mismatch | inventory_id = INV-20251130-00071
# 2026-07-14 14:59:22,564 | ERROR |  Header mismatch | inventory_id = INV-20251130-00072
# 2026-07-14 14:59:22,568 | ERROR |  Header mismatch | inventory_id = INV-20251130-00073
# 2026-07-14 14:59:22,569 | ERROR |  Header mismatch | inventory_id = INV-20251130-00074
# 2026-07-14 14:59:22,571 | ERROR |  Header mismatch | inventory_id = INV-20251130-00075
# 2026-07-14 14:59:22,572 | ERROR |  Header mismatch | inventory_id = INV-20251130-00076
# 2026-07-14 14:59:22,573 | ERROR |  Header mismatch | inventory_id = INV-20251130-00077
# 2026-07-14 14:59:22,574 | ERROR |  Header mismatch | inventory_id = INV-20251130-00078
# 2026-07-14 14:59:22,575 | ERROR |  Header mismatch | inventory_id = INV-20251130-00079
# 2026-07-14 14:59:22,576 | ERROR |  Header mismatch | inventory_id = INV-20251130-00080
# 2026-07-14 14:59:22,577 | ERROR |  Header mismatch | inventory_id = INV-20251130-00081
# 2026-07-14 14:59:22,577 | ERROR |  Header mismatch | inventory_id = INV-20251130-00082
# 2026-07-14 14:59:22,579 | ERROR |  Header mismatch | inventory_id = INV-20251130-00083
# 2026-07-14 14:59:22,580 | ERROR |  Header mismatch | inventory_id = INV-20251130-00084
# 2026-07-14 14:59:22,581 | ERROR |  Header mismatch | inventory_id = INV-20251130-00085
# 2026-07-14 14:59:22,582 | ERROR |  Header mismatch | inventory_id = INV-20251130-00086
# 2026-07-14 14:59:22,583 | ERROR |  Header mismatch | inventory_id = INV-20251130-00087
# 2026-07-14 14:59:22,585 | ERROR |  Header mismatch | inventory_id = INV-20251130-00088
# 2026-07-14 14:59:22,586 | ERROR |  Header mismatch | inventory_id = INV-20251130-00089
# 2026-07-14 14:59:22,587 | ERROR |  Header mismatch | inventory_id = INV-20251130-00090
# 2026-07-14 14:59:22,588 | ERROR |  Header mismatch | inventory_id = INV-20251130-00091
# 2026-07-14 14:59:22,589 | ERROR |  Header mismatch | inventory_id = INV-20251130-00092
# 2026-07-14 14:59:22,590 | ERROR |  Header mismatch | inventory_id = INV-20251130-00093
# 2026-07-14 14:59:22,591 | ERROR |  Header mismatch | inventory_id = INV-20251130-00094
# 2026-07-14 14:59:22,592 | ERROR |  Header mismatch | inventory_id = INV-20251130-00095
# 2026-07-14 14:59:22,593 | ERROR |  Header mismatch | inventory_id = INV-20251130-00096
# 2026-07-14 14:59:22,594 | ERROR |  Header mismatch | inventory_id = INV-20251130-00097
# 2026-07-14 14:59:22,594 | ERROR |  Header mismatch | inventory_id = INV-20251130-00098
# 2026-07-14 14:59:22,597 | ERROR |  Header mismatch | inventory_id = INV-20251130-00099
# 2026-07-14 14:59:22,600 | ERROR |  Header mismatch | inventory_id = INV-20251130-00100
# 2026-07-14 14:59:22,604 | ERROR |  Header mismatch | inventory_id = INV-20251130-00101
# 2026-07-14 14:59:22,607 | ERROR |  Header mismatch | inventory_id = INV-20251130-00102
# 2026-07-14 14:59:22,608 | ERROR |  Header mismatch | inventory_id = INV-20251130-00103
# 2026-07-14 14:59:22,610 | ERROR |  Header mismatch | inventory_id = INV-20251130-00104
# 2026-07-14 14:59:22,611 | ERROR |  Header mismatch | inventory_id = INV-20251130-00105
# 2026-07-14 14:59:22,614 | ERROR |  Header mismatch | inventory_id = INV-20251130-00106
# 2026-07-14 14:59:22,615 | ERROR |  Header mismatch | inventory_id = INV-20251130-00107
# 2026-07-14 14:59:22,616 | ERROR |  Header mismatch | inventory_id = INV-20251130-00108
# 2026-07-14 14:59:22,620 | ERROR |  Header mismatch | inventory_id = INV-20251130-00109
# 2026-07-14 14:59:22,621 | ERROR |  Header mismatch | inventory_id = INV-20251130-00110
# 2026-07-14 14:59:22,626 | ERROR |  Header mismatch | inventory_id = INV-20251130-00111
# 2026-07-14 14:59:22,628 | ERROR |  Header mismatch | inventory_id = INV-20251130-00112
# 2026-07-14 14:59:22,631 | ERROR |  Header mismatch | inventory_id = INV-20251130-00113
# 2026-07-14 14:59:22,632 | ERROR |  Header mismatch | inventory_id = INV-20251130-00114
# 2026-07-14 14:59:22,634 | ERROR |  Header mismatch | inventory_id = INV-20251130-00115
# 2026-07-14 14:59:22,636 | ERROR |  Header mismatch | inventory_id = INV-20251130-00116
# 2026-07-14 14:59:22,639 | ERROR |  Header mismatch | inventory_id = INV-20251130-00117
# 2026-07-14 14:59:22,647 | ERROR |  Header mismatch | inventory_id = INV-20251130-00118
# 2026-07-14 14:59:22,650 | ERROR |  Header mismatch | inventory_id = INV-20251130-00119
# 2026-07-14 14:59:22,651 | ERROR |  Header mismatch | inventory_id = INV-20251130-00120
# 2026-07-14 14:59:22,652 | ERROR |  Header mismatch | inventory_id = INV-20251130-00121
# 2026-07-14 14:59:22,653 | ERROR |  Header mismatch | inventory_id = INV-20251130-00122
# 2026-07-14 14:59:22,656 | ERROR |  Header mismatch | inventory_id = INV-20251130-00123
# 2026-07-14 14:59:22,658 | ERROR |  Header mismatch | inventory_id = INV-20251130-00124
# 2026-07-14 14:59:22,663 | ERROR |  Header mismatch | inventory_id = INV-20251130-00125
# 2026-07-14 14:59:22,666 | ERROR |  Header mismatch | inventory_id = INV-20251130-00126
# 2026-07-14 14:59:22,667 | ERROR |  Header mismatch | inventory_id = INV-20251130-00127
# 2026-07-14 14:59:22,668 | ERROR |  Header mismatch | inventory_id = INV-20251130-00128
# 2026-07-14 14:59:22,669 | ERROR |  Header mismatch | inventory_id = INV-20251130-00129
# 2026-07-14 14:59:22,670 | ERROR |  Header mismatch | inventory_id = INV-20251130-00130
# 2026-07-14 14:59:22,672 | ERROR |  Header mismatch | inventory_id = INV-20251130-00131
# 2026-07-14 14:59:22,678 | ERROR |  Header mismatch | inventory_id = INV-20251130-00132
# 2026-07-14 14:59:22,678 | ERROR |  Header mismatch | inventory_id = INV-20251130-00133
# 2026-07-14 14:59:22,679 | ERROR |  Header mismatch | inventory_id = INV-20251130-00134
# 2026-07-14 14:59:22,681 | ERROR |  Header mismatch | inventory_id = INV-20251130-00135
# 2026-07-14 14:59:22,682 | ERROR |  Header mismatch | inventory_id = INV-20251130-00136
# 2026-07-14 14:59:22,688 | ERROR |  Header mismatch | inventory_id = INV-20251130-00137
# 2026-07-14 14:59:22,690 | ERROR |  Header mismatch | inventory_id = INV-20251130-00138
# 2026-07-14 14:59:22,692 | ERROR |  Header mismatch | inventory_id = INV-20251130-00139
# 2026-07-14 14:59:22,693 | ERROR |  Header mismatch | inventory_id = INV-20251130-00140
# 2026-07-14 14:59:22,695 | ERROR |  Header mismatch | inventory_id = INV-20251130-00141
# 2026-07-14 14:59:22,696 | ERROR |  Header mismatch | inventory_id = INV-20251130-00142
# 2026-07-14 14:59:22,698 | ERROR |  Header mismatch | inventory_id = INV-20251130-00143
# 2026-07-14 14:59:22,700 | ERROR |  Header mismatch | inventory_id = INV-20251130-00144
# 2026-07-14 14:59:22,702 | ERROR |  Header mismatch | inventory_id = INV-20251130-00145
# 2026-07-14 14:59:22,703 | ERROR |  Header mismatch | inventory_id = INV-20251130-00146
# 2026-07-14 14:59:22,704 | ERROR |  Header mismatch | inventory_id = INV-20251130-00147
# 2026-07-14 14:59:22,705 | ERROR |  Header mismatch | inventory_id = INV-20251130-00148
# 2026-07-14 14:59:22,707 | ERROR |  Header mismatch | inventory_id = INV-20251130-00149
# 2026-07-14 14:59:22,711 | ERROR |  Header mismatch | inventory_id = INV-20251130-00150
# 2026-07-14 14:59:22,714 | ERROR |  Header mismatch | inventory_id = INV-20251130-00151
# 2026-07-14 14:59:22,715 | ERROR |  Header mismatch | inventory_id = INV-20251130-00152
# 2026-07-14 14:59:22,716 | ERROR |  Header mismatch | inventory_id = INV-20251130-00153
# 2026-07-14 14:59:22,717 | ERROR |  Header mismatch | inventory_id = INV-20251130-00154
# 2026-07-14 14:59:22,718 | ERROR |  Header mismatch | inventory_id = INV-20251130-00155
# 2026-07-14 14:59:22,720 | ERROR |  Header mismatch | inventory_id = INV-20251130-00156
# 2026-07-14 14:59:22,722 | ERROR |  Header mismatch | inventory_id = INV-20251130-00157
# 2026-07-14 14:59:22,725 | ERROR |  Header mismatch | inventory_id = INV-20251130-00158
# 2026-07-14 14:59:22,732 | ERROR |  Header mismatch | inventory_id = INV-20251130-00159
# 2026-07-14 14:59:22,733 | ERROR |  Header mismatch | inventory_id = INV-20251130-00160
# 2026-07-14 14:59:22,734 | ERROR |  Header mismatch | inventory_id = INV-20251130-00161
# 2026-07-14 14:59:22,735 | ERROR |  Header mismatch | inventory_id = INV-20251130-00162
# 2026-07-14 14:59:22,737 | ERROR |  Header mismatch | inventory_id = INV-20251130-00163
# 2026-07-14 14:59:22,739 | ERROR |  Header mismatch | inventory_id = INV-20251130-00164
# 2026-07-14 14:59:22,744 | ERROR |  Header mismatch | inventory_id = INV-20251130-00165
# 2026-07-14 14:59:22,747 | ERROR |  Header mismatch | inventory_id = INV-20251130-00166
# 2026-07-14 14:59:22,748 | ERROR |  Header mismatch | inventory_id = INV-20251130-00167
# 2026-07-14 14:59:22,750 | ERROR |  Header mismatch | inventory_id = INV-20251130-00168
# 2026-07-14 14:59:22,751 | ERROR |  Header mismatch | inventory_id = INV-20251130-00169
# 2026-07-14 14:59:22,752 | ERROR |  Header mismatch | inventory_id = INV-20251130-00170
# 2026-07-14 14:59:22,756 | ERROR |  Header mismatch | inventory_id = INV-20251130-00171
# 2026-07-14 14:59:22,758 | ERROR |  Header mismatch | inventory_id = INV-20251130-00172
# 2026-07-14 14:59:22,765 | ERROR |  Header mismatch | inventory_id = INV-20251130-00173
# 2026-07-14 14:59:22,767 | ERROR |  Header mismatch | inventory_id = INV-20251130-00174
# 2026-07-14 14:59:22,772 | ERROR |  Header mismatch | inventory_id = INV-20251130-00175
# 2026-07-14 14:59:22,773 | ERROR |  Header mismatch | inventory_id = INV-20251130-00176
# 2026-07-14 14:59:22,777 | ERROR |  Header mismatch | inventory_id = INV-20251130-00177
# 2026-07-14 14:59:22,782 | ERROR |  Header mismatch | inventory_id = INV-20251130-00178
# 2026-07-14 14:59:22,800 | ERROR |  Header mismatch | inventory_id = INV-20251130-00179
# 2026-07-14 14:59:22,803 | ERROR |  Header mismatch | inventory_id = INV-20251130-00180
# 2026-07-14 14:59:22,806 | ERROR |  Header mismatch | inventory_id = INV-20251130-00181
# 2026-07-14 14:59:22,808 | ERROR |  Header mismatch | inventory_id = INV-20251130-00182
# 2026-07-14 14:59:22,809 | ERROR |  Header mismatch | inventory_id = INV-20251130-00183
# 2026-07-14 14:59:22,811 | ERROR |  Header mismatch | inventory_id = INV-20251130-00184
# 2026-07-14 14:59:22,811 | ERROR |  Header mismatch | inventory_id = INV-20251130-00185
# 2026-07-14 14:59:22,815 | ERROR |  Header mismatch | inventory_id = INV-20251130-00186
# 2026-07-14 14:59:22,815 | ERROR |  Header mismatch | inventory_id = INV-20251130-00187
# 2026-07-14 14:59:22,816 | ERROR |  Header mismatch | inventory_id = INV-20251130-00188
# 2026-07-14 14:59:22,818 | ERROR |  Header mismatch | inventory_id = INV-20251130-00189
# 2026-07-14 14:59:22,819 | ERROR |  Header mismatch | inventory_id = INV-20251130-00190
# 2026-07-14 14:59:22,821 | ERROR |  Header mismatch | inventory_id = INV-20251130-00191
# 2026-07-14 14:59:22,822 | ERROR |  Header mismatch | inventory_id = INV-20251130-00192
# 2026-07-14 14:59:22,823 | ERROR |  Header mismatch | inventory_id = INV-20251130-00193
# 2026-07-14 14:59:22,824 | ERROR |  Header mismatch | inventory_id = INV-20251130-00194
# 2026-07-14 14:59:22,829 | ERROR |  Header mismatch | inventory_id = INV-20251130-00195
# 2026-07-14 14:59:22,830 | ERROR |  Header mismatch | inventory_id = INV-20251130-00196
# 2026-07-14 14:59:22,831 | ERROR |  Header mismatch | inventory_id = INV-20251130-00197
# 2026-07-14 14:59:22,832 | ERROR |  Header mismatch | inventory_id = INV-20251130-00198
# 2026-07-14 14:59:22,834 | ERROR |  Header mismatch | inventory_id = INV-20251130-00199
# 2026-07-14 14:59:22,851 | ERROR |  Header mismatch | inventory_id = INV-20251130-00200
# 2026-07-14 14:59:22,853 | ERROR |  Header mismatch | inventory_id = INV-20251130-00201
# 2026-07-14 14:59:22,855 | ERROR |  Header mismatch | inventory_id = INV-20251130-00202
# 2026-07-14 14:59:22,859 | ERROR |  Header mismatch | inventory_id = INV-20251130-00203
# 2026-07-14 14:59:22,862 | ERROR |  Header mismatch | inventory_id = INV-20251130-00204
# 2026-07-14 14:59:22,869 | ERROR |  Header mismatch | inventory_id = INV-20251130-00205
# 2026-07-14 14:59:22,873 | ERROR |  Header mismatch | inventory_id = INV-20251130-00206
# 2026-07-14 14:59:22,876 | ERROR |  Header mismatch | inventory_id = INV-20251130-00207
# 2026-07-14 14:59:22,877 | ERROR |  Header mismatch | inventory_id = INV-20251130-00208
# 2026-07-14 14:59:22,878 | ERROR |  Header mismatch | inventory_id = INV-20251130-00209
# 2026-07-14 14:59:22,878 | ERROR |  Header mismatch | inventory_id = INV-20251130-00210
# 2026-07-14 14:59:22,879 | ERROR |  Header mismatch | inventory_id = INV-20251130-00211
# 2026-07-14 14:59:22,880 | ERROR |  Header mismatch | inventory_id = INV-20251130-00212
# 2026-07-14 14:59:22,881 | ERROR |  Header mismatch | inventory_id = INV-20251130-00213
# 2026-07-14 14:59:22,882 | ERROR |  Header mismatch | inventory_id = INV-20251130-00214
# 2026-07-14 14:59:22,884 | ERROR |  Header mismatch | inventory_id = INV-20251130-00215
# 2026-07-14 14:59:22,887 | ERROR |  Header mismatch | inventory_id = INV-20251130-00216
# 2026-07-14 14:59:22,889 | ERROR |  Header mismatch | inventory_id = INV-20251130-00217
# 2026-07-14 14:59:22,891 | ERROR |  Header mismatch | inventory_id = INV-20251130-00218
# 2026-07-14 14:59:22,892 | ERROR |  Header mismatch | inventory_id = INV-20251130-00219
# 2026-07-14 14:59:22,893 | ERROR |  Header mismatch | inventory_id = INV-20251130-00220
# 2026-07-14 14:59:22,899 | ERROR |  Header mismatch | inventory_id = INV-20251130-00221
# 2026-07-14 14:59:22,900 | ERROR |  Header mismatch | inventory_id = INV-20251130-00222
# 2026-07-14 14:59:22,902 | ERROR |  Header mismatch | inventory_id = INV-20251130-00223
# 2026-07-14 14:59:22,904 | ERROR |  Header mismatch | inventory_id = INV-20251130-00224
# 2026-07-14 14:59:22,907 | ERROR |  Header mismatch | inventory_id = INV-20251130-00225
# 2026-07-14 14:59:22,909 | ERROR |  Header mismatch | inventory_id = INV-20251130-00226
# 2026-07-14 14:59:22,909 | ERROR |  Header mismatch | inventory_id = INV-20251130-00227
# 2026-07-14 14:59:22,911 | ERROR |  Header mismatch | inventory_id = INV-20251130-00228
# 2026-07-14 14:59:22,912 | ERROR |  Header mismatch | inventory_id = INV-20251130-00229
# 2026-07-14 14:59:22,913 | ERROR |  Header mismatch | inventory_id = INV-20251130-00230
# 2026-07-14 14:59:22,914 | ERROR |  Header mismatch | inventory_id = INV-20251130-00231
# 2026-07-14 14:59:22,915 | ERROR |  Header mismatch | inventory_id = INV-20251130-00232
# 2026-07-14 14:59:22,917 | ERROR |  Header mismatch | inventory_id = INV-20251130-00233
# 2026-07-14 14:59:22,921 | ERROR |  Header mismatch | inventory_id = INV-20251130-00234
# 2026-07-14 14:59:22,924 | ERROR |  Header mismatch | inventory_id = INV-20251130-00235
# 2026-07-14 14:59:22,926 | ERROR |  Header mismatch | inventory_id = INV-20251130-00236
# 2026-07-14 14:59:22,928 | ERROR |  Header mismatch | inventory_id = INV-20251130-00237
# 2026-07-14 14:59:22,928 | ERROR |  Header mismatch | inventory_id = INV-20251130-00238
# 2026-07-14 14:59:22,929 | ERROR |  Header mismatch | inventory_id = INV-20251130-00239
# 2026-07-14 14:59:22,931 | ERROR |  Header mismatch | inventory_id = INV-20251130-00240
# 2026-07-14 14:59:22,932 | ERROR |  Header mismatch | inventory_id = INV-20251130-00241
# 2026-07-14 14:59:22,933 | ERROR |  Header mismatch | inventory_id = INV-20251130-00242
# 2026-07-14 14:59:22,934 | ERROR |  Header mismatch | inventory_id = INV-20251130-00243
# 2026-07-14 14:59:22,937 | ERROR |  Header mismatch | inventory_id = INV-20251130-00244
# 2026-07-14 14:59:22,939 | ERROR |  Header mismatch | inventory_id = INV-20251130-00245
# 2026-07-14 14:59:22,941 | ERROR |  Header mismatch | inventory_id = INV-20251130-00246
# 2026-07-14 14:59:22,941 | ERROR |  Header mismatch | inventory_id = INV-20251130-00247
# 2026-07-14 14:59:22,942 | ERROR |  Header mismatch | inventory_id = INV-20251130-00248
# 2026-07-14 14:59:22,944 | ERROR |  Header mismatch | inventory_id = INV-20251130-00249
# 2026-07-14 14:59:22,948 | ERROR |  Header mismatch | inventory_id = INV-20251130-00250
# 2026-07-14 14:59:22,949 | ERROR |  Header mismatch | inventory_id = INV-20251130-00251
# 2026-07-14 14:59:22,950 | ERROR |  Header mismatch | inventory_id = INV-20251130-00252
# 2026-07-14 14:59:22,952 | ERROR |  Header mismatch | inventory_id = INV-20251130-00253
# 2026-07-14 14:59:22,953 | ERROR |  Header mismatch | inventory_id = INV-20251130-00254
# 2026-07-14 14:59:22,954 | ERROR |  Header mismatch | inventory_id = INV-20251130-00255
# 2026-07-14 14:59:22,956 | ERROR |  Header mismatch | inventory_id = INV-20251130-00256
# 2026-07-14 14:59:22,957 | ERROR |  Header mismatch | inventory_id = INV-20251130-00257
# 2026-07-14 14:59:22,959 | ERROR |  Header mismatch | inventory_id = INV-20251130-00258
# 2026-07-14 14:59:22,961 | ERROR |  Header mismatch | inventory_id = INV-20251130-00259
# 2026-07-14 14:59:22,963 | ERROR |  Header mismatch | inventory_id = INV-20251130-00260
# 2026-07-14 14:59:22,965 | ERROR |  Header mismatch | inventory_id = INV-20251130-00261
# 2026-07-14 14:59:22,968 | ERROR |  Header mismatch | inventory_id = INV-20251130-00262
# 2026-07-14 14:59:22,971 | ERROR |  Header mismatch | inventory_id = INV-20251130-00263
# 2026-07-14 14:59:22,972 | ERROR |  Header mismatch | inventory_id = INV-20251130-00264
# 2026-07-14 14:59:22,972 | ERROR |  Header mismatch | inventory_id = INV-20251130-00265
# 2026-07-14 14:59:22,974 | ERROR |  Header mismatch | inventory_id = INV-20251130-00266
# 2026-07-14 14:59:22,976 | ERROR |  Header mismatch | inventory_id = INV-20251130-00267
# 2026-07-14 14:59:22,979 | ERROR |  Header mismatch | inventory_id = INV-20251130-00268
# 2026-07-14 14:59:22,986 | ERROR |  Header mismatch | inventory_id = INV-20251130-00269
# 2026-07-14 14:59:22,989 | ERROR |  Header mismatch | inventory_id = INV-20251130-00270
# 2026-07-14 14:59:22,992 | ERROR |  Header mismatch | inventory_id = INV-20251130-00271
# 2026-07-14 14:59:23,000 | ERROR |  Header mismatch | inventory_id = INV-20251130-00272
# 2026-07-14 14:59:23,004 | ERROR |  Header mismatch | inventory_id = INV-20251130-00273
# 2026-07-14 14:59:23,005 | ERROR |  Header mismatch | inventory_id = INV-20251130-00274
# 2026-07-14 14:59:23,007 | ERROR |  Header mismatch | inventory_id = INV-20251130-00275
# 2026-07-14 14:59:23,008 | ERROR |  Header mismatch | inventory_id = INV-20251130-00276
# 2026-07-14 14:59:23,017 | ERROR |  Header mismatch | inventory_id = INV-20251130-00277
# 2026-07-14 14:59:23,023 | ERROR |  Header mismatch | inventory_id = INV-20251130-00278
# 2026-07-14 14:59:23,025 | ERROR |  Header mismatch | inventory_id = INV-20251130-00279
# 2026-07-14 14:59:23,031 | ERROR |  Header mismatch | inventory_id = INV-20251130-00280
# 2026-07-14 14:59:23,039 | ERROR |  Header mismatch | inventory_id = INV-20251130-00281
# 2026-07-14 14:59:23,042 | ERROR |  Header mismatch | inventory_id = INV-20251130-00282
# 2026-07-14 14:59:23,046 | ERROR |  Header mismatch | inventory_id = INV-20251130-00283
# 2026-07-14 14:59:23,048 | ERROR |  Header mismatch | inventory_id = INV-20251130-00284
# 2026-07-14 14:59:23,054 | ERROR |  Header mismatch | inventory_id = INV-20251130-00285
# 2026-07-14 14:59:23,059 | ERROR |  Header mismatch | inventory_id = INV-20251130-00286
# 2026-07-14 14:59:23,062 | ERROR |  Header mismatch | inventory_id = INV-20251130-00287
# 2026-07-14 14:59:23,066 | ERROR |  Header mismatch | inventory_id = INV-20251130-00288
# 2026-07-14 14:59:23,071 | ERROR |  Header mismatch | inventory_id = INV-20251130-00289
# 2026-07-14 14:59:23,075 | ERROR |  Header mismatch | inventory_id = INV-20251130-00290
# 2026-07-14 14:59:23,076 | ERROR |  Header mismatch | inventory_id = INV-20251130-00291
# 2026-07-14 14:59:23,077 | ERROR |  Header mismatch | inventory_id = INV-20251130-00292
# 2026-07-14 14:59:23,086 | ERROR |  Header mismatch | inventory_id = INV-20251130-00293
# 2026-07-14 14:59:23,089 | ERROR |  Header mismatch | inventory_id = INV-20251130-00294
# 2026-07-14 14:59:23,093 | ERROR |  Header mismatch | inventory_id = INV-20251130-00295
# 2026-07-14 14:59:23,101 | ERROR |  Header mismatch | inventory_id = INV-20251130-00296
# 2026-07-14 14:59:23,107 | ERROR |  Header mismatch | inventory_id = INV-20251130-00297
# 2026-07-14 14:59:23,108 | ERROR |  Header mismatch | inventory_id = INV-20251130-00298
# 2026-07-14 14:59:23,110 | ERROR |  Header mismatch | inventory_id = INV-20251130-00299
# 2026-07-14 14:59:23,112 | ERROR |  Header mismatch | inventory_id = INV-20251130-00300
# 2026-07-14 14:59:23,115 | ERROR |  Header mismatch | inventory_id = INV-20251231-00301
# 2026-07-14 14:59:23,116 | ERROR |  Header mismatch | inventory_id = INV-20251231-00302
# 2026-07-14 14:59:23,120 | ERROR |  Header mismatch | inventory_id = INV-20251231-00303
# 2026-07-14 14:59:23,121 | ERROR |  Header mismatch | inventory_id = INV-20251231-00304
# 2026-07-14 14:59:23,122 | ERROR |  Header mismatch | inventory_id = INV-20251231-00305
# 2026-07-14 14:59:23,123 | ERROR |  Header mismatch | inventory_id = INV-20251231-00306
# 2026-07-14 14:59:23,123 | ERROR |  Header mismatch | inventory_id = INV-20251231-00307
# 2026-07-14 14:59:23,125 | ERROR |  Header mismatch | inventory_id = INV-20251231-00308
# 2026-07-14 14:59:23,130 | ERROR |  Header mismatch | inventory_id = INV-20251231-00309
# 2026-07-14 14:59:23,131 | ERROR |  Header mismatch | inventory_id = INV-20251231-00310
# 2026-07-14 14:59:23,132 | ERROR |  Header mismatch | inventory_id = INV-20251231-00311
# 2026-07-14 14:59:23,133 | ERROR |  Header mismatch | inventory_id = INV-20251231-00312
# 2026-07-14 14:59:23,134 | ERROR |  Header mismatch | inventory_id = INV-20251231-00313
# 2026-07-14 14:59:23,137 | ERROR |  Header mismatch | inventory_id = INV-20251231-00314
# 2026-07-14 14:59:23,139 | ERROR |  Header mismatch | inventory_id = INV-20251231-00315
# 2026-07-14 14:59:23,145 | ERROR |  Header mismatch | inventory_id = INV-20251231-00316
# 2026-07-14 14:59:23,147 | ERROR |  Header mismatch | inventory_id = INV-20251231-00317
# 2026-07-14 14:59:23,148 | ERROR |  Header mismatch | inventory_id = INV-20251231-00318
# 2026-07-14 14:59:23,151 | ERROR |  Header mismatch | inventory_id = INV-20251231-00319
# 2026-07-14 14:59:23,153 | ERROR |  Header mismatch | inventory_id = INV-20251231-00320
# 2026-07-14 14:59:23,157 | ERROR |  Header mismatch | inventory_id = INV-20251231-00321
# 2026-07-14 14:59:23,160 | ERROR |  Header mismatch | inventory_id = INV-20251231-00322
# 2026-07-14 14:59:23,162 | ERROR |  Header mismatch | inventory_id = INV-20251231-00323
# 2026-07-14 14:59:23,164 | ERROR |  Header mismatch | inventory_id = INV-20251231-00324
# 2026-07-14 14:59:23,169 | ERROR |  Header mismatch | inventory_id = INV-20251231-00325
# 2026-07-14 14:59:23,170 | ERROR |  Header mismatch | inventory_id = INV-20251231-00326
# 2026-07-14 14:59:23,170 | ERROR |  Header mismatch | inventory_id = INV-20251231-00327
# 2026-07-14 14:59:23,171 | ERROR |  Header mismatch | inventory_id = INV-20251231-00328
# 2026-07-14 14:59:23,172 | ERROR |  Header mismatch | inventory_id = INV-20251231-00329
# 2026-07-14 14:59:23,175 | ERROR |  Header mismatch | inventory_id = INV-20251231-00330
# 2026-07-14 14:59:23,180 | ERROR |  Header mismatch | inventory_id = INV-20251231-00331
# 2026-07-14 14:59:23,181 | ERROR |  Header mismatch | inventory_id = INV-20251231-00332
# 2026-07-14 14:59:23,183 | ERROR |  Header mismatch | inventory_id = INV-20251231-00333
# 2026-07-14 14:59:23,184 | ERROR |  Header mismatch | inventory_id = INV-20251231-00334
# 2026-07-14 14:59:23,186 | ERROR |  Header mismatch | inventory_id = INV-20251231-00335
# 2026-07-14 14:59:23,187 | ERROR |  Header mismatch | inventory_id = INV-20251231-00336
# 2026-07-14 14:59:23,189 | ERROR |  Header mismatch | inventory_id = INV-20251231-00337
# 2026-07-14 14:59:23,195 | ERROR |  Header mismatch | inventory_id = INV-20251231-00338
# 2026-07-14 14:59:23,202 | ERROR |  Header mismatch | inventory_id = INV-20251231-00339
# 2026-07-14 14:59:23,204 | ERROR |  Header mismatch | inventory_id = INV-20251231-00340
# 2026-07-14 14:59:23,207 | ERROR |  Header mismatch | inventory_id = INV-20251231-00341
# 2026-07-14 14:59:23,209 | ERROR |  Header mismatch | inventory_id = INV-20251231-00342
# 2026-07-14 14:59:23,211 | ERROR |  Header mismatch | inventory_id = INV-20251231-00343
# 2026-07-14 14:59:23,212 | ERROR |  Header mismatch | inventory_id = INV-20251231-00344
# 2026-07-14 14:59:23,213 | ERROR |  Header mismatch | inventory_id = INV-20251231-00345
# 2026-07-14 14:59:23,215 | ERROR |  Header mismatch | inventory_id = INV-20251231-00346
# 2026-07-14 14:59:23,216 | ERROR |  Header mismatch | inventory_id = INV-20251231-00347
# 2026-07-14 14:59:23,220 | ERROR |  Header mismatch | inventory_id = INV-20251231-00348
# 2026-07-14 14:59:23,222 | ERROR |  Header mismatch | inventory_id = INV-20251231-00349
# 2026-07-14 14:59:23,223 | ERROR |  Header mismatch | inventory_id = INV-20251231-00350
# 2026-07-14 14:59:23,224 | ERROR |  Header mismatch | inventory_id = INV-20251231-00351
# 2026-07-14 14:59:23,227 | ERROR |  Header mismatch | inventory_id = INV-20251231-00352
# 2026-07-14 14:59:23,234 | ERROR |  Header mismatch | inventory_id = INV-20251231-00353
# 2026-07-14 14:59:23,235 | ERROR |  Header mismatch | inventory_id = INV-20251231-00354
# 2026-07-14 14:59:23,236 | ERROR |  Header mismatch | inventory_id = INV-20251231-00355
# 2026-07-14 14:59:23,237 | ERROR |  Header mismatch | inventory_id = INV-20251231-00356
# 2026-07-14 14:59:23,238 | ERROR |  Header mismatch | inventory_id = INV-20251231-00357
# 2026-07-14 14:59:23,239 | ERROR |  Header mismatch | inventory_id = INV-20251231-00358
# 2026-07-14 14:59:23,240 | ERROR |  Header mismatch | inventory_id = INV-20251231-00359
# 2026-07-14 14:59:23,243 | ERROR |  Header mismatch | inventory_id = INV-20251231-00360
# 2026-07-14 14:59:23,245 | ERROR |  Header mismatch | inventory_id = INV-20251231-00361
# 2026-07-14 14:59:23,252 | ERROR |  Header mismatch | inventory_id = INV-20251231-00362
# 2026-07-14 14:59:23,254 | ERROR |  Header mismatch | inventory_id = INV-20251231-00363
# 2026-07-14 14:59:23,256 | ERROR |  Header mismatch | inventory_id = INV-20251231-00364
# 2026-07-14 14:59:23,258 | ERROR |  Header mismatch | inventory_id = INV-20251231-00365
# 2026-07-14 14:59:23,259 | ERROR |  Header mismatch | inventory_id = INV-20251231-00366
# 2026-07-14 14:59:23,261 | ERROR |  Header mismatch | inventory_id = INV-20251231-00367
# 2026-07-14 14:59:23,262 | ERROR |  Header mismatch | inventory_id = INV-20251231-00368
# 2026-07-14 14:59:23,266 | ERROR |  Header mismatch | inventory_id = INV-20251231-00369
# 2026-07-14 14:59:23,268 | ERROR |  Header mismatch | inventory_id = INV-20251231-00370
# 2026-07-14 14:59:23,270 | ERROR |  Header mismatch | inventory_id = INV-20251231-00371
# 2026-07-14 14:59:23,272 | ERROR |  Header mismatch | inventory_id = INV-20251231-00372
# 2026-07-14 14:59:23,273 | ERROR |  Header mismatch | inventory_id = INV-20251231-00373
# 2026-07-14 14:59:23,274 | ERROR |  Header mismatch | inventory_id = INV-20251231-00374
# 2026-07-14 14:59:23,275 | ERROR |  Header mismatch | inventory_id = INV-20251231-00375
# 2026-07-14 14:59:23,276 | ERROR |  Header mismatch | inventory_id = INV-20251231-00376
# 2026-07-14 14:59:23,276 | ERROR |  Header mismatch | inventory_id = INV-20251231-00377
# 2026-07-14 14:59:23,277 | ERROR |  Header mismatch | inventory_id = INV-20251231-00378
# 2026-07-14 14:59:23,278 | ERROR |  Header mismatch | inventory_id = INV-20251231-00379
# 2026-07-14 14:59:23,280 | ERROR |  Header mismatch | inventory_id = INV-20251231-00380
# 2026-07-14 14:59:23,285 | ERROR |  Header mismatch | inventory_id = INV-20251231-00381
# 2026-07-14 14:59:23,288 | ERROR |  Header mismatch | inventory_id = INV-20251231-00382
# 2026-07-14 14:59:23,291 | ERROR |  Header mismatch | inventory_id = INV-20251231-00383
# 2026-07-14 14:59:23,296 | ERROR |  Header mismatch | inventory_id = INV-20251231-00384
# 2026-07-14 14:59:23,298 | ERROR |  Header mismatch | inventory_id = INV-20251231-00385
# 2026-07-14 14:59:23,300 | ERROR |  Header mismatch | inventory_id = INV-20251231-00386
# 2026-07-14 14:59:23,302 | ERROR |  Header mismatch | inventory_id = INV-20251231-00387
# 2026-07-14 14:59:23,306 | ERROR |  Header mismatch | inventory_id = INV-20251231-00388
# 2026-07-14 14:59:23,308 | ERROR |  Header mismatch | inventory_id = INV-20251231-00389
# 2026-07-14 14:59:23,309 | ERROR |  Header mismatch | inventory_id = INV-20251231-00390
# 2026-07-14 14:59:23,313 | ERROR |  Header mismatch | inventory_id = INV-20251231-00391
# 2026-07-14 14:59:23,316 | ERROR |  Header mismatch | inventory_id = INV-20251231-00392
# 2026-07-14 14:59:23,319 | ERROR |  Header mismatch | inventory_id = INV-20251231-00393
# 2026-07-14 14:59:23,321 | ERROR |  Header mismatch | inventory_id = INV-20251231-00394
# 2026-07-14 14:59:23,323 | ERROR |  Header mismatch | inventory_id = INV-20251231-00395
# 2026-07-14 14:59:23,326 | ERROR |  Header mismatch | inventory_id = INV-20251231-00396
# 2026-07-14 14:59:23,327 | ERROR |  Header mismatch | inventory_id = INV-20251231-00397
# 2026-07-14 14:59:23,328 | ERROR |  Header mismatch | inventory_id = INV-20251231-00398
# 2026-07-14 14:59:23,330 | ERROR |  Header mismatch | inventory_id = INV-20251231-00399
# 2026-07-14 14:59:23,332 | ERROR |  Header mismatch | inventory_id = INV-20251231-00400
# 2026-07-14 14:59:23,339 | ERROR |  Header mismatch | inventory_id = INV-20251231-00401
# 2026-07-14 14:59:23,341 | ERROR |  Header mismatch | inventory_id = INV-20251231-00402
# 2026-07-14 14:59:23,342 | ERROR |  Header mismatch | inventory_id = INV-20251231-00403
# 2026-07-14 14:59:23,343 | ERROR |  Header mismatch | inventory_id = INV-20251231-00404
# 2026-07-14 14:59:23,344 | ERROR |  Header mismatch | inventory_id = INV-20251231-00405
# 2026-07-14 14:59:23,345 | ERROR |  Header mismatch | inventory_id = INV-20251231-00406
# 2026-07-14 14:59:23,347 | ERROR |  Header mismatch | inventory_id = INV-20251231-00407
# 2026-07-14 14:59:23,350 | ERROR |  Header mismatch | inventory_id = INV-20251231-00408
# 2026-07-14 14:59:23,352 | ERROR |  Header mismatch | inventory_id = INV-20251231-00409
# 2026-07-14 14:59:23,353 | ERROR |  Header mismatch | inventory_id = INV-20251231-00410
# 2026-07-14 14:59:23,356 | ERROR |  Header mismatch | inventory_id = INV-20251231-00411
# 2026-07-14 14:59:23,357 | ERROR |  Header mismatch | inventory_id = INV-20251231-00412
# 2026-07-14 14:59:23,361 | ERROR |  Header mismatch | inventory_id = INV-20251231-00413
# 2026-07-14 14:59:23,362 | ERROR |  Header mismatch | inventory_id = INV-20251231-00414
# 2026-07-14 14:59:23,364 | ERROR |  Header mismatch | inventory_id = INV-20251231-00415
# 2026-07-14 14:59:23,365 | ERROR |  Header mismatch | inventory_id = INV-20251231-00416
# 2026-07-14 14:59:23,365 | ERROR |  Header mismatch | inventory_id = INV-20251231-00417
# 2026-07-14 14:59:23,369 | ERROR |  Header mismatch | inventory_id = INV-20251231-00418
# 2026-07-14 14:59:23,371 | ERROR |  Header mismatch | inventory_id = INV-20251231-00419
# 2026-07-14 14:59:23,372 | ERROR |  Header mismatch | inventory_id = INV-20251231-00420
# 2026-07-14 14:59:23,372 | ERROR |  Header mismatch | inventory_id = INV-20251231-00421
# 2026-07-14 14:59:23,373 | ERROR |  Header mismatch | inventory_id = INV-20251231-00422
# 2026-07-14 14:59:23,378 | ERROR |  Header mismatch | inventory_id = INV-20251231-00423
# 2026-07-14 14:59:23,379 | ERROR |  Header mismatch | inventory_id = INV-20251231-00424
# 2026-07-14 14:59:23,379 | ERROR |  Header mismatch | inventory_id = INV-20251231-00425
# 2026-07-14 14:59:23,382 | ERROR |  Header mismatch | inventory_id = INV-20251231-00426
# 2026-07-14 14:59:23,383 | ERROR |  Header mismatch | inventory_id = INV-20251231-00427
# 2026-07-14 14:59:23,384 | ERROR |  Header mismatch | inventory_id = INV-20251231-00428
# 2026-07-14 14:59:23,386 | ERROR |  Header mismatch | inventory_id = INV-20251231-00429
# 2026-07-14 14:59:23,388 | ERROR |  Header mismatch | inventory_id = INV-20251231-00430
# 2026-07-14 14:59:23,389 | ERROR |  Header mismatch | inventory_id = INV-20251231-00431
# 2026-07-14 14:59:23,391 | ERROR |  Header mismatch | inventory_id = INV-20251231-00432
# 2026-07-14 14:59:23,392 | ERROR |  Header mismatch | inventory_id = INV-20251231-00433
# 2026-07-14 14:59:23,393 | ERROR |  Header mismatch | inventory_id = INV-20251231-00434
# 2026-07-14 14:59:23,394 | ERROR |  Header mismatch | inventory_id = INV-20251231-00435
# 2026-07-14 14:59:23,395 | ERROR |  Header mismatch | inventory_id = INV-20251231-00436
# 2026-07-14 14:59:23,397 | ERROR |  Header mismatch | inventory_id = INV-20251231-00437
# 2026-07-14 14:59:23,398 | ERROR |  Header mismatch | inventory_id = INV-20251231-00438
# 2026-07-14 14:59:23,399 | ERROR |  Header mismatch | inventory_id = INV-20251231-00439
# 2026-07-14 14:59:23,400 | ERROR |  Header mismatch | inventory_id = INV-20251231-00440
# 2026-07-14 14:59:23,401 | ERROR |  Header mismatch | inventory_id = INV-20251231-00441
# 2026-07-14 14:59:23,401 | ERROR |  Header mismatch | inventory_id = INV-20251231-00442
# 2026-07-14 14:59:23,402 | ERROR |  Header mismatch | inventory_id = INV-20251231-00443
# 2026-07-14 14:59:23,403 | ERROR |  Header mismatch | inventory_id = INV-20251231-00444
# 2026-07-14 14:59:23,409 | ERROR |  Header mismatch | inventory_id = INV-20251231-00445
# 2026-07-14 14:59:23,412 | ERROR |  Header mismatch | inventory_id = INV-20251231-00446
# 2026-07-14 14:59:23,414 | ERROR |  Header mismatch | inventory_id = INV-20251231-00447
# 2026-07-14 14:59:23,417 | ERROR |  Header mismatch | inventory_id = INV-20251231-00448
# 2026-07-14 14:59:23,418 | ERROR |  Header mismatch | inventory_id = INV-20251231-00449
# 2026-07-14 14:59:23,420 | ERROR |  Header mismatch | inventory_id = INV-20251231-00450
# 2026-07-14 14:59:23,424 | ERROR |  Header mismatch | inventory_id = INV-20251231-00451
# 2026-07-14 14:59:23,427 | ERROR |  Header mismatch | inventory_id = INV-20251231-00452
# 2026-07-14 14:59:23,428 | ERROR |  Header mismatch | inventory_id = INV-20251231-00453
# 2026-07-14 14:59:23,429 | ERROR |  Header mismatch | inventory_id = INV-20251231-00454
# 2026-07-14 14:59:23,430 | ERROR |  Header mismatch | inventory_id = INV-20251231-00455
# 2026-07-14 14:59:23,433 | ERROR |  Header mismatch | inventory_id = INV-20251231-00456
# 2026-07-14 14:59:23,434 | ERROR |  Header mismatch | inventory_id = INV-20251231-00457
# 2026-07-14 14:59:23,436 | ERROR |  Header mismatch | inventory_id = INV-20251231-00458
# 2026-07-14 14:59:23,438 | ERROR |  Header mismatch | inventory_id = INV-20251231-00459
# 2026-07-14 14:59:23,440 | ERROR |  Header mismatch | inventory_id = INV-20251231-00460
# 2026-07-14 14:59:23,443 | ERROR |  Header mismatch | inventory_id = INV-20251231-00461
# 2026-07-14 14:59:23,445 | ERROR |  Header mismatch | inventory_id = INV-20251231-00462
# 2026-07-14 14:59:23,446 | ERROR |  Header mismatch | inventory_id = INV-20251231-00463
# 2026-07-14 14:59:23,447 | ERROR |  Header mismatch | inventory_id = INV-20251231-00464
# 2026-07-14 14:59:23,450 | ERROR |  Header mismatch | inventory_id = INV-20251231-00465
# 2026-07-14 14:59:23,451 | ERROR |  Header mismatch | inventory_id = INV-20251231-00466
# 2026-07-14 14:59:23,452 | ERROR |  Header mismatch | inventory_id = INV-20251231-00467
# 2026-07-14 14:59:23,453 | ERROR |  Header mismatch | inventory_id = INV-20251231-00468
# 2026-07-14 14:59:23,453 | ERROR |  Header mismatch | inventory_id = INV-20251231-00469
# 2026-07-14 14:59:23,454 | ERROR |  Header mismatch | inventory_id = INV-20251231-00470
# 2026-07-14 14:59:23,455 | ERROR |  Header mismatch | inventory_id = INV-20251231-00471
# 2026-07-14 14:59:23,458 | ERROR |  Header mismatch | inventory_id = INV-20251231-00472
# 2026-07-14 14:59:23,461 | ERROR |  Header mismatch | inventory_id = INV-20251231-00473
# 2026-07-14 14:59:23,465 | ERROR |  Header mismatch | inventory_id = INV-20251231-00474
# 2026-07-14 14:59:23,466 | ERROR |  Header mismatch | inventory_id = INV-20251231-00475
# 2026-07-14 14:59:23,467 | ERROR |  Header mismatch | inventory_id = INV-20251231-00476
# 2026-07-14 14:59:23,468 | ERROR |  Header mismatch | inventory_id = INV-20251231-00477
# 2026-07-14 14:59:23,469 | ERROR |  Header mismatch | inventory_id = INV-20251231-00478
# 2026-07-14 14:59:23,470 | ERROR |  Header mismatch | inventory_id = INV-20251231-00479
# 2026-07-14 14:59:23,471 | ERROR |  Header mismatch | inventory_id = INV-20251231-00480
# 2026-07-14 14:59:23,471 | ERROR |  Header mismatch | inventory_id = INV-20251231-00481
# 2026-07-14 14:59:23,473 | ERROR |  Header mismatch | inventory_id = INV-20251231-00482
# 2026-07-14 14:59:23,474 | ERROR |  Header mismatch | inventory_id = INV-20251231-00483
# 2026-07-14 14:59:23,475 | ERROR |  Header mismatch | inventory_id = INV-20251231-00484
# 2026-07-14 14:59:23,476 | ERROR |  Header mismatch | inventory_id = INV-20251231-00485
# 2026-07-14 14:59:23,477 | ERROR |  Header mismatch | inventory_id = INV-20251231-00486
# 2026-07-14 14:59:23,478 | ERROR |  Header mismatch | inventory_id = INV-20251231-00487
# 2026-07-14 14:59:23,479 | ERROR |  Header mismatch | inventory_id = INV-20251231-00488
# 2026-07-14 14:59:23,480 | ERROR |  Header mismatch | inventory_id = INV-20251231-00489
# 2026-07-14 14:59:23,481 | ERROR |  Header mismatch | inventory_id = INV-20251231-00490
# 2026-07-14 14:59:23,482 | ERROR |  Header mismatch | inventory_id = INV-20251231-00491
# 2026-07-14 14:59:23,486 | ERROR |  Header mismatch | inventory_id = INV-20251231-00492
# 2026-07-14 14:59:23,487 | ERROR |  Header mismatch | inventory_id = INV-20251231-00493
# 2026-07-14 14:59:23,487 | ERROR |  Header mismatch | inventory_id = INV-20251231-00494
# 2026-07-14 14:59:23,488 | ERROR |  Header mismatch | inventory_id = INV-20251231-00495
# 2026-07-14 14:59:23,489 | ERROR |  Header mismatch | inventory_id = INV-20251231-00496
# 2026-07-14 14:59:23,489 | ERROR |  Header mismatch | inventory_id = INV-20251231-00497
# 2026-07-14 14:59:23,490 | ERROR |  Header mismatch | inventory_id = INV-20251231-00498
# 2026-07-14 14:59:23,495 | ERROR |  Header mismatch | inventory_id = INV-20251231-00499
# 2026-07-14 14:59:23,498 | ERROR |  Header mismatch | inventory_id = INV-20251231-00500
# 2026-07-14 14:59:23,501 | ERROR |  Header mismatch | inventory_id = INV-20251231-00501
# 2026-07-14 14:59:23,503 | ERROR |  Header mismatch | inventory_id = INV-20251231-00502
# 2026-07-14 14:59:23,506 | ERROR |  Header mismatch | inventory_id = INV-20251231-00503
# 2026-07-14 14:59:23,508 | ERROR |  Header mismatch | inventory_id = INV-20251231-00504
# 2026-07-14 14:59:23,512 | ERROR |  Header mismatch | inventory_id = INV-20251231-00505
# 2026-07-14 14:59:23,514 | ERROR |  Header mismatch | inventory_id = INV-20251231-00506
# 2026-07-14 14:59:23,517 | ERROR |  Header mismatch | inventory_id = INV-20251231-00507
# 2026-07-14 14:59:23,518 | ERROR |  Header mismatch | inventory_id = INV-20251231-00508
# 2026-07-14 14:59:23,519 | ERROR |  Header mismatch | inventory_id = INV-20251231-00509
# 2026-07-14 14:59:23,520 | ERROR |  Header mismatch | inventory_id = INV-20251231-00510
# 2026-07-14 14:59:23,521 | ERROR |  Header mismatch | inventory_id = INV-20251231-00511
# 2026-07-14 14:59:23,522 | ERROR |  Header mismatch | inventory_id = INV-20251231-00512
# 2026-07-14 14:59:23,523 | ERROR |  Header mismatch | inventory_id = INV-20251231-00513
# 2026-07-14 14:59:23,524 | ERROR |  Header mismatch | inventory_id = INV-20251231-00514
# 2026-07-14 14:59:23,528 | ERROR |  Header mismatch | inventory_id = INV-20251231-00515
# 2026-07-14 14:59:23,529 | ERROR |  Header mismatch | inventory_id = INV-20251231-00516
# 2026-07-14 14:59:23,530 | ERROR |  Header mismatch | inventory_id = INV-20251231-00517
# 2026-07-14 14:59:23,534 | ERROR |  Header mismatch | inventory_id = INV-20251231-00518
# 2026-07-14 14:59:23,536 | ERROR |  Header mismatch | inventory_id = INV-20251231-00519
# 2026-07-14 14:59:23,539 | ERROR |  Header mismatch | inventory_id = INV-20251231-00520
# 2026-07-14 14:59:23,543 | ERROR |  Header mismatch | inventory_id = INV-20251231-00521
# 2026-07-14 14:59:23,545 | ERROR |  Header mismatch | inventory_id = INV-20251231-00522
# 2026-07-14 14:59:23,548 | ERROR |  Header mismatch | inventory_id = INV-20251231-00523
# 2026-07-14 14:59:23,550 | ERROR |  Header mismatch | inventory_id = INV-20251231-00524
# 2026-07-14 14:59:23,552 | ERROR |  Header mismatch | inventory_id = INV-20251231-00525
# 2026-07-14 14:59:23,553 | ERROR |  Header mismatch | inventory_id = INV-20251231-00526
# 2026-07-14 14:59:23,554 | ERROR |  Header mismatch | inventory_id = INV-20251231-00527
# 2026-07-14 14:59:23,555 | ERROR |  Header mismatch | inventory_id = INV-20251231-00528
# 2026-07-14 14:59:23,558 | ERROR |  Header mismatch | inventory_id = INV-20251231-00529
# 2026-07-14 14:59:23,561 | ERROR |  Header mismatch | inventory_id = INV-20251231-00530
# 2026-07-14 14:59:23,562 | ERROR |  Header mismatch | inventory_id = INV-20251231-00531
# 2026-07-14 14:59:23,564 | ERROR |  Header mismatch | inventory_id = INV-20251231-00532
# 2026-07-14 14:59:23,565 | ERROR |  Header mismatch | inventory_id = INV-20251231-00533
# 2026-07-14 14:59:23,569 | ERROR |  Header mismatch | inventory_id = INV-20251231-00534
# 2026-07-14 14:59:23,570 | ERROR |  Header mismatch | inventory_id = INV-20251231-00535
# 2026-07-14 14:59:23,572 | ERROR |  Header mismatch | inventory_id = INV-20251231-00536
# 2026-07-14 14:59:23,576 | ERROR |  Header mismatch | inventory_id = INV-20251231-00537
# 2026-07-14 14:59:23,580 | ERROR |  Header mismatch | inventory_id = INV-20251231-00538
# 2026-07-14 14:59:23,584 | ERROR |  Header mismatch | inventory_id = INV-20251231-00539
# 2026-07-14 14:59:23,587 | ERROR |  Header mismatch | inventory_id = INV-20251231-00540
# 2026-07-14 14:59:23,595 | ERROR |  Header mismatch | inventory_id = INV-20251231-00541
# 2026-07-14 14:59:23,596 | ERROR |  Header mismatch | inventory_id = INV-20251231-00542
# 2026-07-14 14:59:23,597 | ERROR |  Header mismatch | inventory_id = INV-20251231-00543
# 2026-07-14 14:59:23,601 | ERROR |  Header mismatch | inventory_id = INV-20251231-00544
# 2026-07-14 14:59:23,604 | ERROR |  Header mismatch | inventory_id = INV-20251231-00545
# 2026-07-14 14:59:23,611 | ERROR |  Header mismatch | inventory_id = INV-20251231-00546
# 2026-07-14 14:59:23,613 | ERROR |  Header mismatch | inventory_id = INV-20251231-00547
# 2026-07-14 14:59:23,617 | ERROR |  Header mismatch | inventory_id = INV-20251231-00548
# 2026-07-14 14:59:23,632 | ERROR |  Header mismatch | inventory_id = INV-20251231-00549
# 2026-07-14 14:59:23,644 | ERROR |  Header mismatch | inventory_id = INV-20251231-00550
# ...
# 2026-07-14 14:59:24,255 | ERROR |  Header mismatch | inventory_id = INV-20260131-00719
# 2026-07-14 14:59:24,257 | ERROR |  Header mismatch | inventory_id = INV-20260131-00720
# 2026-07-14 14:59:24,257 | ERROR |  Header mismatch | inventory_id = INV-20260131-00721
# 2026-07-14 14:59:24,258 | ERROR |  Header mismatch | inventory_id = INV-20260131-00722
# 2026-07-14 14:59:24,259 | ERROR |  Header mismatch | inventory_id = INV-20260131-00723
# 2026-07-14 14:59:24,260 | ERROR |  Header mismatch | inventory_id = INV-20260131-00724
# 2026-07-14 14:59:24,261 | ERROR |  Header mismatch | inventory_id = INV-20260131-00725
# 2026-07-14 14:59:24,264 | ERROR |  Header mismatch | inventory_id = INV-20260131-00726
# 2026-07-14 14:59:24,265 | ERROR |  Header mismatch | inventory_id = INV-20260131-00727
# 2026-07-14 14:59:24,269 | ERROR |  Header mismatch | inventory_id = INV-20260131-00728
# 2026-07-14 14:59:24,271 | ERROR |  Header mismatch | inventory_id = INV-20260131-00729
# 2026-07-14 14:59:24,277 | ERROR |  Header mismatch | inventory_id = INV-20260131-00730
# 2026-07-14 14:59:24,280 | ERROR |  Header mismatch | inventory_id = INV-20260131-00731
# 2026-07-14 14:59:24,284 | ERROR |  Header mismatch | inventory_id = INV-20260131-00732
# 2026-07-14 14:59:24,285 | ERROR |  Header mismatch | inventory_id = INV-20260131-00733
# 2026-07-14 14:59:24,286 | ERROR |  Header mismatch | inventory_id = INV-20260131-00734
# 2026-07-14 14:59:24,287 | ERROR |  Header mismatch | inventory_id = INV-20260131-00735
# 2026-07-14 14:59:24,288 | ERROR |  Header mismatch | inventory_id = INV-20260131-00736
# 2026-07-14 14:59:24,290 | ERROR |  Header mismatch | inventory_id = INV-20260131-00737
# 2026-07-14 14:59:24,291 | ERROR |  Header mismatch | inventory_id = INV-20260131-00738
# 2026-07-14 14:59:24,299 | ERROR |  Header mismatch | inventory_id = INV-20260131-00739
# 2026-07-14 14:59:24,300 | ERROR |  Header mismatch | inventory_id = INV-20260131-00740
# 2026-07-14 14:59:24,301 | ERROR |  Header mismatch | inventory_id = INV-20260131-00741
# 2026-07-14 14:59:24,303 | ERROR |  Header mismatch | inventory_id = INV-20260131-00742
# 2026-07-14 14:59:24,305 | ERROR |  Header mismatch | inventory_id = INV-20260131-00743
# 2026-07-14 14:59:24,306 | ERROR |  Header mismatch | inventory_id = INV-20260131-00744
# 2026-07-14 14:59:24,307 | ERROR |  Header mismatch | inventory_id = INV-20260131-00745
# 2026-07-14 14:59:24,309 | ERROR |  Header mismatch | inventory_id = INV-20260131-00746
# 2026-07-14 14:59:24,313 | ERROR |  Header mismatch | inventory_id = INV-20260131-00747
# 2026-07-14 14:59:24,315 | ERROR |  Header mismatch | inventory_id = INV-20260131-00748
# 2026-07-14 14:59:24,321 | ERROR |  Header mismatch | inventory_id = INV-20260131-00749
# 2026-07-14 14:59:24,323 | ERROR |  Header mismatch | inventory_id = INV-20260131-00750
# 2026-07-14 14:59:24,323 | ERROR |  Header mismatch | inventory_id = INV-20260131-00751
# 2026-07-14 14:59:24,325 | ERROR |  Header mismatch | inventory_id = INV-20260131-00752
# 2026-07-14 14:59:24,326 | ERROR |  Header mismatch | inventory_id = INV-20260131-00753
# 2026-07-14 14:59:24,329 | ERROR |  Header mismatch | inventory_id = INV-20260131-00754
# 2026-07-14 14:59:24,330 | ERROR |  Header mismatch | inventory_id = INV-20260131-00755
# 2026-07-14 14:59:24,336 | ERROR |  Header mismatch | inventory_id = INV-20260131-00756
# 2026-07-14 14:59:24,337 | ERROR |  Header mismatch | inventory_id = INV-20260131-00757
# 2026-07-14 14:59:24,338 | ERROR |  Header mismatch | inventory_id = INV-20260131-00758
# 2026-07-14 14:59:24,340 | ERROR |  Header mismatch | inventory_id = INV-20260131-00759
# 2026-07-14 14:59:24,343 | ERROR |  Header mismatch | inventory_id = INV-20260131-00760
# 2026-07-14 14:59:24,348 | ERROR |  Header mismatch | inventory_id = INV-20260131-00761
# 2026-07-14 14:59:24,352 | ERROR |  Header mismatch | inventory_id = INV-20260131-00762
# 2026-07-14 14:59:24,353 | ERROR |  Header mismatch | inventory_id = INV-20260131-00763
# 2026-07-14 14:59:24,354 | ERROR |  Header mismatch | inventory_id = INV-20260131-00764
# 2026-07-14 14:59:24,356 | ERROR |  Header mismatch | inventory_id = INV-20260131-00765
# 2026-07-14 14:59:24,357 | ERROR |  Header mismatch | inventory_id = INV-20260131-00766
# 2026-07-14 14:59:24,359 | ERROR |  Header mismatch | inventory_id = INV-20260131-00767
# 2026-07-14 14:59:24,360 | ERROR |  Header mismatch | inventory_id = INV-20260131-00768
# 2026-07-14 14:59:24,363 | ERROR |  Header mismatch | inventory_id = INV-20260131-00769
# 2026-07-14 14:59:24,363 | ERROR |  Header mismatch | inventory_id = INV-20260131-00770
# 2026-07-14 14:59:24,364 | ERROR |  Header mismatch | inventory_id = INV-20260131-00771
# 2026-07-14 14:59:24,365 | ERROR |  Header mismatch | inventory_id = INV-20260131-00772
# 2026-07-14 14:59:24,371 | ERROR |  Header mismatch | inventory_id = INV-20260131-00773
# 2026-07-14 14:59:24,374 | ERROR |  Header mismatch | inventory_id = INV-20260131-00774
# 2026-07-14 14:59:24,377 | ERROR |  Header mismatch | inventory_id = INV-20260131-00775
# 2026-07-14 14:59:24,380 | ERROR |  Header mismatch | inventory_id = INV-20260131-00776
# 2026-07-14 14:59:24,381 | ERROR |  Header mismatch | inventory_id = INV-20260131-00777
# 2026-07-14 14:59:24,385 | ERROR |  Header mismatch | inventory_id = INV-20260131-00778
# 2026-07-14 14:59:24,389 | ERROR |  Header mismatch | inventory_id = INV-20260131-00779
# 2026-07-14 14:59:24,391 | ERROR |  Header mismatch | inventory_id = INV-20260131-00780
# 2026-07-14 14:59:24,393 | ERROR |  Header mismatch | inventory_id = INV-20260131-00781
# 2026-07-14 14:59:24,394 | ERROR |  Header mismatch | inventory_id = INV-20260131-00782
# 2026-07-14 14:59:24,395 | ERROR |  Header mismatch | inventory_id = INV-20260131-00783
# 2026-07-14 14:59:24,397 | ERROR |  Header mismatch | inventory_id = INV-20260131-00784
# 2026-07-14 14:59:24,397 | ERROR |  Header mismatch | inventory_id = INV-20260131-00785
# 2026-07-14 14:59:24,398 | ERROR |  Header mismatch | inventory_id = INV-20260131-00786
# 2026-07-14 14:59:24,399 | ERROR |  Header mismatch | inventory_id = INV-20260131-00787
# 2026-07-14 14:59:24,402 | ERROR |  Header mismatch | inventory_id = INV-20260131-00788
# 2026-07-14 14:59:24,404 | ERROR |  Header mismatch | inventory_id = INV-20260131-00789
# 2026-07-14 14:59:24,407 | ERROR |  Header mismatch | inventory_id = INV-20260131-00790
# 2026-07-14 14:59:24,409 | ERROR |  Header mismatch | inventory_id = INV-20260131-00791
# 2026-07-14 14:59:24,413 | ERROR |  Header mismatch | inventory_id = INV-20260131-00792
# 2026-07-14 14:59:24,415 | ERROR |  Header mismatch | inventory_id = INV-20260131-00793
# 2026-07-14 14:59:24,417 | ERROR |  Header mismatch | inventory_id = INV-20260131-00794
# 2026-07-14 14:59:24,417 | ERROR |  Header mismatch | inventory_id = INV-20260131-00795
# 2026-07-14 14:59:24,419 | ERROR |  Header mismatch | inventory_id = INV-20260131-00796
# 2026-07-14 14:59:24,422 | ERROR |  Header mismatch | inventory_id = INV-20260131-00797
# 2026-07-14 14:59:24,423 | ERROR |  Header mismatch | inventory_id = INV-20260131-00798
# 2026-07-14 14:59:24,427 | ERROR |  Header mismatch | inventory_id = INV-20260131-00799
# 2026-07-14 14:59:24,429 | ERROR |  Header mismatch | inventory_id = INV-20260131-00800
# 2026-07-14 14:59:24,430 | ERROR |  Header mismatch | inventory_id = INV-20260131-00801
# 2026-07-14 14:59:24,431 | ERROR |  Header mismatch | inventory_id = INV-20260131-00802
# 2026-07-14 14:59:24,433 | ERROR |  Header mismatch | inventory_id = INV-20260131-00803
# 2026-07-14 14:59:24,437 | ERROR |  Header mismatch | inventory_id = INV-20260131-00804
# 2026-07-14 14:59:24,438 | ERROR |  Header mismatch | inventory_id = INV-20260131-00805
# 2026-07-14 14:59:24,441 | ERROR |  Header mismatch | inventory_id = INV-20260131-00806
# 2026-07-14 14:59:24,442 | ERROR |  Header mismatch | inventory_id = INV-20260131-00807
# 2026-07-14 14:59:24,444 | ERROR |  Header mismatch | inventory_id = INV-20260131-00808
# 2026-07-14 14:59:24,445 | ERROR |  Header mismatch | inventory_id = INV-20260131-00809
# 2026-07-14 14:59:24,447 | ERROR |  Header mismatch | inventory_id = INV-20260131-00810
# 2026-07-14 14:59:24,449 | ERROR |  Header mismatch | inventory_id = INV-20260131-00811
# 2026-07-14 14:59:24,453 | ERROR |  Header mismatch | inventory_id = INV-20260131-00812
# 2026-07-14 14:59:24,454 | ERROR |  Header mismatch | inventory_id = INV-20260131-00813
# 2026-07-14 14:59:24,456 | ERROR |  Header mismatch | inventory_id = INV-20260131-00814
# 2026-07-14 14:59:24,458 | ERROR |  Header mismatch | inventory_id = INV-20260131-00815
# 2026-07-14 14:59:24,461 | ERROR |  Header mismatch | inventory_id = INV-20260131-00816
# 2026-07-14 14:59:24,462 | ERROR |  Header mismatch | inventory_id = INV-20260131-00817
# 2026-07-14 14:59:24,463 | ERROR |  Header mismatch | inventory_id = INV-20260131-00818
# 2026-07-14 14:59:24,464 | ERROR |  Header mismatch | inventory_id = INV-20260131-00819
# 2026-07-14 14:59:24,465 | ERROR |  Header mismatch | inventory_id = INV-20260131-00820
# 2026-07-14 14:59:24,467 | ERROR |  Header mismatch | inventory_id = INV-20260131-00821
# 2026-07-14 14:59:24,469 | ERROR |  Header mismatch | inventory_id = INV-20260131-00822
# 2026-07-14 14:59:24,470 | ERROR |  Header mismatch | inventory_id = INV-20260131-00823
# 2026-07-14 14:59:24,472 | ERROR |  Header mismatch | inventory_id = INV-20260131-00824
# 2026-07-14 14:59:24,473 | ERROR |  Header mismatch | inventory_id = INV-20260131-00825
# 2026-07-14 14:59:24,475 | ERROR |  Header mismatch | inventory_id = INV-20260131-00826
# 2026-07-14 14:59:24,475 | ERROR |  Header mismatch | inventory_id = INV-20260131-00827
# 2026-07-14 14:59:24,476 | ERROR |  Header mismatch | inventory_id = INV-20260131-00828
# 2026-07-14 14:59:24,478 | ERROR |  Header mismatch | inventory_id = INV-20260131-00829
# 2026-07-14 14:59:24,479 | ERROR |  Header mismatch | inventory_id = INV-20260131-00830
# 2026-07-14 14:59:24,479 | ERROR |  Header mismatch | inventory_id = INV-20260131-00831
# 2026-07-14 14:59:24,480 | ERROR |  Header mismatch | inventory_id = INV-20260131-00832
# 2026-07-14 14:59:24,481 | ERROR |  Header mismatch | inventory_id = INV-20260131-00833
# 2026-07-14 14:59:24,483 | ERROR |  Header mismatch | inventory_id = INV-20260131-00834
# 2026-07-14 14:59:24,486 | ERROR |  Header mismatch | inventory_id = INV-20260131-00835
# 2026-07-14 14:59:24,489 | ERROR |  Header mismatch | inventory_id = INV-20260131-00836
# 2026-07-14 14:59:24,494 | ERROR |  Header mismatch | inventory_id = INV-20260131-00837
# 2026-07-14 14:59:24,496 | ERROR |  Header mismatch | inventory_id = INV-20260131-00838
# 2026-07-14 14:59:24,499 | ERROR |  Header mismatch | inventory_id = INV-20260131-00839
# 2026-07-14 14:59:24,500 | ERROR |  Header mismatch | inventory_id = INV-20260131-00840
# 2026-07-14 14:59:24,503 | ERROR |  Header mismatch | inventory_id = INV-20260131-00841
# 2026-07-14 14:59:24,508 | ERROR |  Header mismatch | inventory_id = INV-20260131-00842
# 2026-07-14 14:59:24,514 | ERROR |  Header mismatch | inventory_id = INV-20260131-00843
# 2026-07-14 14:59:24,520 | ERROR |  Header mismatch | inventory_id = INV-20260131-00844
# 2026-07-14 14:59:24,537 | ERROR |  Header mismatch | inventory_id = INV-20260131-00845
# 2026-07-14 14:59:24,541 | ERROR |  Header mismatch | inventory_id = INV-20260131-00846
# 2026-07-14 14:59:24,545 | ERROR |  Header mismatch | inventory_id = INV-20260131-00847
# 2026-07-14 14:59:24,548 | ERROR |  Header mismatch | inventory_id = INV-20260131-00848
# 2026-07-14 14:59:24,549 | ERROR |  Header mismatch | inventory_id = INV-20260131-00849
# 2026-07-14 14:59:24,551 | ERROR |  Header mismatch | inventory_id = INV-20260131-00850
# 2026-07-14 14:59:24,556 | ERROR |  Header mismatch | inventory_id = INV-20260131-00851
# 2026-07-14 14:59:24,558 | ERROR |  Header mismatch | inventory_id = INV-20260131-00852
# 2026-07-14 14:59:24,560 | ERROR |  Header mismatch | inventory_id = INV-20260131-00853
# 2026-07-14 14:59:24,564 | ERROR |  Header mismatch | inventory_id = INV-20260131-00854
# 2026-07-14 14:59:24,568 | ERROR |  Header mismatch | inventory_id = INV-20260131-00855
# 2026-07-14 14:59:24,570 | ERROR |  Header mismatch | inventory_id = INV-20260131-00856
# 2026-07-14 14:59:24,571 | ERROR |  Header mismatch | inventory_id = INV-20260131-00857
# 2026-07-14 14:59:24,572 | ERROR |  Header mismatch | inventory_id = INV-20260131-00858
# 2026-07-14 14:59:24,573 | ERROR |  Header mismatch | inventory_id = INV-20260131-00859
# 2026-07-14 14:59:24,573 | ERROR |  Header mismatch | inventory_id = INV-20260131-00860
# 2026-07-14 14:59:24,576 | ERROR |  Header mismatch | inventory_id = INV-20260131-00861
# 2026-07-14 14:59:24,580 | ERROR |  Header mismatch | inventory_id = INV-20260131-00862
# 2026-07-14 14:59:24,585 | ERROR |  Header mismatch | inventory_id = INV-20260131-00863
# 2026-07-14 14:59:24,586 | ERROR |  Header mismatch | inventory_id = INV-20260131-00864
# 2026-07-14 14:59:24,588 | ERROR |  Header mismatch | inventory_id = INV-20260131-00865
# 2026-07-14 14:59:24,591 | ERROR |  Header mismatch | inventory_id = INV-20260131-00866
# 2026-07-14 14:59:24,593 | ERROR |  Header mismatch | inventory_id = INV-20260131-00867
# 2026-07-14 14:59:24,598 | ERROR |  Header mismatch | inventory_id = INV-20260131-00868
# 2026-07-14 14:59:24,603 | ERROR |  Header mismatch | inventory_id = INV-20260131-00869
# 2026-07-14 14:59:24,603 | ERROR |  Header mismatch | inventory_id = INV-20260131-00870
# 2026-07-14 14:59:24,606 | ERROR |  Header mismatch | inventory_id = INV-20260131-00871
# 2026-07-14 14:59:24,611 | ERROR |  Header mismatch | inventory_id = INV-20260131-00872
# 2026-07-14 14:59:24,615 | ERROR |  Header mismatch | inventory_id = INV-20260131-00873
# 2026-07-14 14:59:24,616 | ERROR |  Header mismatch | inventory_id = INV-20260131-00874
# 2026-07-14 14:59:24,617 | ERROR |  Header mismatch | inventory_id = INV-20260131-00875
# 2026-07-14 14:59:24,621 | ERROR |  Header mismatch | inventory_id = INV-20260131-00876
# 2026-07-14 14:59:24,627 | ERROR |  Header mismatch | inventory_id = INV-20260131-00877
# 2026-07-14 14:59:24,627 | ERROR |  Header mismatch | inventory_id = INV-20260131-00878
# 2026-07-14 14:59:24,630 | ERROR |  Header mismatch | inventory_id = INV-20260131-00879
# 2026-07-14 14:59:24,635 | ERROR |  Header mismatch | inventory_id = INV-20260131-00880
# 2026-07-14 14:59:24,637 | ERROR |  Header mismatch | inventory_id = INV-20260131-00881
# 2026-07-14 14:59:24,639 | ERROR |  Header mismatch | inventory_id = INV-20260131-00882
# 2026-07-14 14:59:24,642 | ERROR |  Header mismatch | inventory_id = INV-20260131-00883
# 2026-07-14 14:59:24,647 | ERROR |  Header mismatch | inventory_id = INV-20260131-00884
# 2026-07-14 14:59:24,653 | ERROR |  Header mismatch | inventory_id = INV-20260131-00885
# 2026-07-14 14:59:24,658 | ERROR |  Header mismatch | inventory_id = INV-20260131-00886
# 2026-07-14 14:59:24,659 | ERROR |  Header mismatch | inventory_id = INV-20260131-00887
# 2026-07-14 14:59:24,662 | ERROR |  Header mismatch | inventory_id = INV-20260131-00888
# 2026-07-14 14:59:24,663 | ERROR |  Header mismatch | inventory_id = INV-20260131-00889
# 2026-07-14 14:59:24,665 | ERROR |  Header mismatch | inventory_id = INV-20260131-00890
# 2026-07-14 14:59:24,673 | ERROR |  Header mismatch | inventory_id = INV-20260131-00891
# 2026-07-14 14:59:24,675 | ERROR |  Header mismatch | inventory_id = INV-20260131-00892
# 2026-07-14 14:59:24,677 | ERROR |  Header mismatch | inventory_id = INV-20260131-00893
# 2026-07-14 14:59:24,677 | ERROR |  Header mismatch | inventory_id = INV-20260131-00894
# 2026-07-14 14:59:24,678 | ERROR |  Header mismatch | inventory_id = INV-20260131-00895
# 2026-07-14 14:59:24,680 | ERROR |  Header mismatch | inventory_id = INV-20260131-00896
# 2026-07-14 14:59:24,680 | ERROR |  Header mismatch | inventory_id = INV-20260131-00897
# 2026-07-14 14:59:24,681 | ERROR |  Header mismatch | inventory_id = INV-20260131-00898
# 2026-07-14 14:59:24,683 | ERROR |  Header mismatch | inventory_id = INV-20260131-00899
# 2026-07-14 14:59:24,685 | ERROR |  Header mismatch | inventory_id = INV-20260131-00900
# 2026-07-14 14:59:24,688 | INFO | Validation Complete | Valid rows = 0, Invalid rows = 900
